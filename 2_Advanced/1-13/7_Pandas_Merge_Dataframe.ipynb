# %%
# Import Libaries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Datasets
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_original = df.copy()
df_uk = df_original[df_original['job_country'] == 'United Kingdom'].copy()
# Add a column containing the month the job was posted. But a written month not numerical
df_uk['job_posted_month'] = df_uk['job_posted_date'].dt.strftime('%B')

# Pivot the df_uk

df_uk_pivot = df_uk.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

#this sorts month in alphabetical order.

# remove month as index, create month number column & sort by this monthly number

df_uk_pivot.reset_index(inplace=True)

df_uk_pivot['month_no'] = pd.to_datetime(df_uk_pivot['job_posted_month'], format='%B').dt.month # Added a column with the month number


df_uk_pivot.sort_values('month_no', inplace=True)
df_uk_pivot.set_index('job_posted_month', inplace=True)
df_uk_pivot.drop(columns='month_no', inplace=True)

# %%
df_uk_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                         46               3          1467
# February                        23               4          1051
# March                           47               5           712
# April                           29               7           561
# May                             23               1           614
# June                            14               2           736
# July                            38               5           892
# August                          22               7           610
# September                      111              32          1112
# October                        195              57          1175
# November                       155              39           840
# December                       124              31           712
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    1253            1142                          8
# February                   1009             859                         10
# March                       789             699                          8
# April                       611             519                          8
# May                         645             486                         11
# June                        862             636                          3
# July                        960             646                         13
# August                      863             657                         15
# September                  1191             898                         51
# October                    1348             959                         62
# November                   1242             895                         50
# December                   1034             752                         78
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           169                   347
# February                          140                   301
# March                              91                   224
# April                              63                   155
# May                                60                   227
# June                              102                   292
# July                              116                   321
# August                             96                   247
# September                         139                   320
# October                           168                   331
# November                          102                   359
# December                          110                   213
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                             326                 20
# February                            212                 10
# March                               179                 19
# April                               123                 18
# May                                 153                 16
# June                                154                  4
# July                                184                 12
# August                              181                 13
# September                           221                116
# October                             243                126
# November                            197                 90
# December                            194                 97

# %%
df_uk_software_pivot = pd.read_csv('https://lukeb.co/software_csv', index_col='job_posted_month')

# %%
df_uk_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
df_uk_merged = df_uk_pivot.merge(df_uk_software_pivot, on='job_posted_month')

# %%
top_5 = (
    df_uk_merged
    .sum()
    .sort_values(ascending=False)
    .head()
    .index
    .tolist()
)

df_uk_merged
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                         46               3          1467
# February                        23               4          1051
# March                           47               5           712
# April                           29               7           561
# May                             23               1           614
# June                            14               2           736
# July                            38               5           892
# August                          22               7           610
# September                      111              32          1112
# October                        195              57          1175
# November                       155              39           840
# December                       124              31           712
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    1253            1142                          8
# February                   1009             859                         10
# March                       789             699                          8
# April                       611             519                          8
# May                         645             486                         11
# June                        862             636                          3
# July                        960             646                         13
# August                      863             657                         15
# September                  1191             898                         51
# October                    1348             959                         62
# November                   1242             895                         50
# December                   1034             752                         78
#
#                   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           169                   347
# February                          140                   301
# March                              91                   224
# April                              63                   155
# May                                60                   227
# June                              102                   292
# July                              116                   321
# August                             96                   247
# September                         139                   320
# October                           168                   331
# November                          102                   359
# December                          110                   213
#
#                   Senior Data Scientist  Software Engineer  \
# job_posted_month
# January                             326                 20
# February                            212                 10
# March                               179                 19
# April                               123                 18
# May                                 153                 16
# June                                154                  4
# July                                184                 12
# August                              181                 13
# September                           221                116
# October                             243                126
# November                            197                 90
# December                            194                 97
#
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
df_uk_merged[top_5].plot(kind='line')
plt.title('Monthly Job Postings for Top Tech Jobs - UK')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.ylim(0, 21000)
plt.legend()
plt.show()
