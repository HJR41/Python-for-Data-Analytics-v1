# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_original = df.copy()

# %%
len_10 = len(df_original)*0.1

# %%
len_10 = int(len_10)

# %%
print(len(df_original))

print(len_10)
# Out:
# 785741
# 78574

# %%
df_sample = df_original.copy()

# %%
df_sample = df_sample.sample(len_10)

# %%
df_sample
# Out:
#           job_title_short                                          job_title  \
# 7857        Data Engineer                                      Data Engineer
# 330081   Business Analyst  Busines Process Improvement Analyst. Santiago,...
# 15145      Data Scientist                                     Import Analyst
# 660233       Data Analyst                               Actuary Data Analyst
# 86461      Data Scientist                                  Sr Data Scientist
# ...                   ...                                                ...
# 509702      Data Engineer                                  Big Data Engineer
# 755520      Data Engineer                         Lead Support Data Engineer
# 502655  Software Engineer                              DA - Python + Pyspark
# 144285     Data Scientist             Trainee Data Science/Analytics (m/w/d)
# 167767  Software Engineer                              Senior Apple Engineer
#
#                   job_location                   job_via job_schedule_type  \
# 7857              South Africa                via Indeed         Full-time
# 330081                   Chile              via Sercanto         Full-time
# 15145            Kyiv, Ukraine             via Rabota.ua         Full-time
# 660233            Hartford, CT              via LinkedIn         Full-time
# 86461   Amsterdam, Netherlands              via The Muse         Full-time
# ...                        ...                       ...               ...
# 509702                Anywhere              via LinkedIn         Full-time
# 755520          Birmingham, UK  via FOX 5 San Diego Jobs         Full-time
# 502655                   India              via LinkedIn         Full-time
# 144285      Wuppertal, Germany             via Stepstone         Full-time
# 167767                 Czechia           via Trabajo.org         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 7857                 False             South Africa 2023-06-19 13:37:19
# 330081               False                    Chile 2023-12-03 23:35:14
# 15145                False                  Ukraine 2023-01-07 13:18:04
# 660233               False  New York, United States 2023-07-05 10:00:35
# 86461                False              Netherlands 2023-08-21 00:40:23
# ...                    ...                      ...                 ...
# 509702                True                    Spain 2023-01-13 11:26:05
# 755520               False           United Kingdom 2023-04-03 20:31:56
# 502655               False                    India 2023-06-30 11:15:04
# 144285               False                  Germany 2023-06-21 08:23:37
# 167767               False                  Czechia 2023-07-11 16:00:36
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 7857                     True                 False    South Africa
# 330081                  False                 False           Chile
# 15145                    True                 False         Ukraine
# 660233                  False                  True   United States
# 86461                   False                 False     Netherlands
# ...                       ...                   ...             ...
# 509702                  False                 False           Spain
# 755520                   True                 False  United Kingdom
# 502655                   True                 False           India
# 144285                  False                 False         Germany
# 167767                   True                 False         Czechia
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 7857          None              NaN              NaN
# 330081        None              NaN              NaN
# 15145         None              NaN              NaN
# 660233        None              NaN              NaN
# 86461         None              NaN              NaN
# ...            ...              ...              ...
# 509702        None              NaN              NaN
# 755520        None              NaN              NaN
# 502655        None              NaN              NaN
# 144285        None              NaN              NaN
# 167767        None              NaN              NaN
#
#                       company_name  \
# 7857                    Sabenza IT
# 330081                Confidencial
# 15145   Metro Cash & Carry Ukraine
# 660233                       Jobot
# 86461                         Uber
# ...                            ...
# 509702              Mirai Advisory
# 755520   Gleeson Recruitment Group
# 502655                       Capco
# 144285                      BARMER
# 167767              ANDERSON HOARE
#
#                                                job_skills  \
# 7857        ['python', 'sql', 'nosql', 'dynamodb', 'aws']
# 330081                                               None
# 15145                                                None
# 660233                                          ['excel']
# 86461                   ['sql', 'r', 'python', 'tableau']
# ...                                                   ...
# 509702         ['java', 'scala', 'aws', 'spark', 'linux']
# 755520            ['sql', 't-sql', 'azure', 'databricks']
# 502655  ['sql', 'scala', 'java', 'python', 'spark', 'p...
# 144285                                            ['sql']
# 167767                ['swift', 'macos', 'excel', 'flow']
#
#                                           job_type_skills
# 7857    {'cloud': ['aws'], 'databases': ['dynamodb'], ...
# 330081                                               None
# 15145                                                None
# 660233                       {'analyst_tools': ['excel']}
# 86461   {'analyst_tools': ['tableau'], 'programming': ...
# ...                                                   ...
# 509702  {'cloud': ['aws'], 'libraries': ['spark'], 'os...
# 755520  {'cloud': ['azure', 'databricks'], 'programmin...
# 502655  {'libraries': ['spark', 'pyspark', 'pandas'], ...
# 144285                           {'programming': ['sql']}
# 167767  {'analyst_tools': ['excel'], 'os': ['macos'], ...
#
# [78574 rows x 17 columns]
