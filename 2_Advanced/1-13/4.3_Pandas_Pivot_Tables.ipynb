# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df_original = df.copy()

# %%
df_pivot_table = df_original.copy()

# %%
df_pivot_table.pivot_table(values='salary_year_avg', index='job_country', columns='company_name', aggfunc='median')
# Out:
# company_name  #twiceasnice Recruiting  /dev/color  0nward Select  \
# job_country
# Albania                           NaN         NaN            NaN
# Algeria                           NaN         NaN            NaN
# Argentina                         NaN         NaN            NaN
# Armenia                           NaN         NaN            NaN
# Australia                         NaN         NaN            NaN
# ...                               ...         ...            ...
# Uruguay                           NaN         NaN            NaN
# Uzbekistan                        NaN         NaN            NaN
# Vietnam                           NaN         NaN            NaN
# Zambia                            NaN         NaN            NaN
# Zimbabwe                          NaN         NaN            NaN
#
# company_name  1 Point System  1 Point System LLC.  1-800-FLOWERS.COM, INC.  \
# job_country
# Albania                  NaN                  NaN                      NaN
# ...

# %%
df_pivot_table = df_pivot_table[df_pivot_table['job_title_short'] == 'Data Scientist']
#now Dataframe only includes rows where job_title_short is Data Scientist

# %%
df_pivot_table = df_pivot_table[df_pivot_table['salary_year_avg'] > 200_000].head(10)

# %%
df_pivot_table.pivot_table(values='salary_year_avg', index=['company_name', 'job_country'], aggfunc='median')
# Out:
#                                    salary_year_avg
# company_name        job_country
# ByteDance           United States         224500.0
# Demandbase, Inc     United States         220832.0
# Dropbox             United States         206500.0
# Home Depot / THD    United States         240000.0
# INgroovesMusicGroup United States         250000.0
# TikTok              United States         259750.0
# eSmartloan          United States         211000.0
